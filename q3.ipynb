# %%
import matplotlib.pyplot as plt
import numpy as np

mk = np.matrix('0.3 -1; -1 5')
mk1 = np.linalg.cholesky(mk)
x, y = np.random.multivariate_normal([0, 2], mk, 400).T
plt.plot(x, y, 'x')
plt.axis([-5, 5, -20, 20])
plt.show()
